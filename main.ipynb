# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('exoplanet_data.csv')
df = data.copy(deep=True)

# %%
df.sample(10)
# Out:
#          kepid kepoi_name    kepler_name koi_disposition koi_pdisposition  \
# 6574   9363944  K05660.01            NaN       CANDIDATE        CANDIDATE
# 9563  10156110  K07989.01            NaN  FALSE POSITIVE   FALSE POSITIVE
# 2414   9837661  K02715.02  Kepler-1321 c       CONFIRMED        CANDIDATE
# 2729  11508644  K03101.01  Kepler-1426 b       CONFIRMED        CANDIDATE
# 1789   8973129  K02286.01  Kepler-1176 b       CONFIRMED        CANDIDATE
# 5738   9602562  K03985.01            NaN  FALSE POSITIVE   FALSE POSITIVE
# 8972   3766353  K06359.01            NaN  FALSE POSITIVE   FALSE POSITIVE
# 547    6047498  K01013.01            NaN  FALSE POSITIVE   FALSE POSITIVE
# 6073   9605552  K03102.01            NaN       CANDIDATE        CANDIDATE
# 1868   6666233  K02306.01            NaN  FALSE POSITIVE   FALSE POSITIVE
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 6574        NaN              0              0              0              0
# 9563      0.000              0              0              1              1
# 2414      1.000              0              0              0              0
# 2729      0.998              0              0              0              0
# 1789      1.000              0              0              0              0
# 5738      0.000              0              0              1              1
# 8972      0.000              0              1              0              0
# 547       0.000              0              1              0              0
# 6073        NaN              0              0              0              0
# 1868      0.000              0              1              0              0
#
#       koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 6574  402.209690   369.508600      0.3779        5.2980      472.5     10.03
# 9563    4.856035   135.993300      0.1340        3.0780       76.7      1.05
# 2414    2.226496   133.371950      0.0480        1.7073     1839.1      2.10
# 2729   14.256327   133.409710      0.8940        4.7960      206.1      1.73
# 1789   24.173824   135.624710      0.2510        3.0560      532.6      2.21
# 5738    3.556536   133.517200      0.7120        8.7000      202.5      1.70
# 8972    2.666962   133.719065      1.2760        2.4774     7583.4     40.68
# 547     0.518727   133.676312      1.1990        1.2520      714.1     19.07
# 6073    9.321084   138.099460      0.0815        1.8100      294.2      0.61
# 1868    0.512407   132.240449      0.3010        1.0579      329.2      1.03
#
#       koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num koi_tce_delivname  \
# 6574    452.0       9.86            9.5               1.0        q1_q16_tce
# 9563   1266.0     607.42            8.2               1.0   q1_q17_dr25_tce
# 2414    697.0      55.76           36.0               2.0   q1_q17_dr25_tce
# 2729    797.0      95.22           14.3               1.0   q1_q17_dr25_tce
# 1789    595.0      29.69           21.5               1.0   q1_q17_dr25_tce
# 5738   1272.0     619.57           23.1               1.0   q1_q17_dr25_tce
# 8972   1469.0    1104.26          249.5               1.0   q1_q17_dr25_tce
# 547    1965.0    3537.27           93.3               1.0   q1_q17_dr25_tce
# 6073    394.0       5.67            6.1               NaN               NaN
# 1868   1255.0     583.45           46.1               1.0   q1_q17_dr25_tce
#
#       koi_steff  koi_slogg  koi_srad         ra        dec  koi_kepmag
# 6574     4961.0      3.131     4.649  299.03528  45.869289      13.660
# 9563     6469.0      4.385     1.193  297.00977  47.121021      14.826
# 2414     3640.0      4.744     0.503  294.52859  46.640968      16.835
# 2729     6140.0      4.455     1.027  292.54575  49.416969      15.192
# 1789     5468.0      4.427     0.968  297.91974  45.274158      15.056
# 5738     5950.0      4.395     1.114  297.13220  46.256489      14.377
# 8972     6609.0      4.484     0.974  296.05377  38.894260      13.968
# 547      5572.0      4.597     0.762  293.38556  41.349819      15.348
# 6073     3773.0      4.925     0.350  297.96048  46.227921      15.983
# 1868     3862.0      4.690     0.563  282.28439  42.154190      14.780

# %%
df = df.drop('kepler_name', axis=1).dropna()

# %%
df.shape
# Out:
# (7994, 26)

# %%
X = df.select_dtypes(include=['float64'])

# %%
X.sample(5)
# Out:
#       koi_score  koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  \
# 5312      0.000    4.045063   132.232226       0.529       3.22222   360180.0
# 2029      1.000    2.668313   131.688230       0.333       2.41410      266.2
# 5018      0.000  157.322639   222.900363       0.888      21.92320   153930.0
# 720       0.000    0.782046   134.021400       1.244       1.79450    16185.0
# 2876      0.962   27.943024   136.869700       0.052       6.12500      308.6
#
#       koi_prad  koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  \
# 5312     67.94   1143.0     402.77          483.9               1.0
# 2029      1.48   1252.0     581.38           23.3               1.0
# 5018     56.66    351.0       3.61         1386.8               1.0
# 720      45.05   2070.0    4332.10          272.3               1.0
# 2876      2.21    718.0      62.74           12.3               1.0
#
#       koi_steff  koi_slogg  koi_srad         ra        dec  koi_kepmag
# 5312     5780.0      4.438     1.000  294.58798  40.167068      17.705
# 2029     5806.0      4.528     0.899  296.07568  45.627060      15.553
# 5018     6109.0      4.472     0.989  284.51367  45.120300      15.291
# 720      6113.0      4.463     0.995  290.26767  44.712849      14.912
# 2876     6468.0      4.363     1.250  292.80722  38.884232      15.243

# %%
labels = df['koi_pdisposition']

# %%
y = labels.replace({'FALSE POSITIVE': 0, 'CANDIDATE': 1})

# %%
X = pd.DataFrame(StandardScaler().fit_transform(X), columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = lr_model.predict(X_test)

print(f'Accuracy: {accuracy_score(y_test, pred)*100:0.2f}%')
# Out:
# Accuracy: 95.31%

# %%
print('Top 5 most predictive features:')

coefs = lr_model.coef_.flatten()
weights = np.abs(coefs)

weights_df = pd.DataFrame(weights, columns=['weight'])
weights_df.sort_values(by='weight', ascending=False, inplace=True)
weights_df.reset_index(inplace=True)

for index in np.array(weights_df['index'])[:5]:
    print(f'{X.columns[index]} : {coefs[index]:0.4f}')

print('(refer to README for feature descriptions)')
# Out:
# Top 5 most predictive features:
# koi_score : 2.9879
# koi_depth : -1.9462
# koi_prad : -1.9185
# koi_teq : -1.1261
# koi_impact : -0.7299
# (refer to README for feature descriptions)
